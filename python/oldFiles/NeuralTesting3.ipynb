# %%
from python.Visualization.NeuralTesting import *
# Out:
# [50.0, 150.0, 198.0]

# %%
# --------------------------
# Example usage with sample data
graphNodes = ['1000-1999','2000-2999', '3000-3999', '4000-4999', '5000-5999', '6000-6999', '7000-7999']
Cplex_3   = [4706, 14718, 19624, 24101, 28721, 33011, 36992]
randomizer= [3323, 9755, 13140, 15335, 18892, 21856, 23738]
All_cut   = [4406, 13249, 17072, 20867, 24285, 26969, 28994]

# Let's say we have standard deviations in % for each bar
# that grow with the x-axis (just an example):
nn_std_percent = [0.92, 0.99, 1.2, 1.5, 1.6, 1.8, 2]
nn_std_percent_ran = [ 1.92, 1.99, 2.2, 2.5, 2.6, 2.8, 3]
# nn_std_percent_GCN = apply_percentage( nn_std_percent, [90,90,90,90,90,90,90]),
# nn_std_percent_cplex = apply_percentage( nn_std_percent, [90,90,90,90,90,90,90])

# barPlot_3(
#     heuristic_cut=Cplex_3,
#     neural_cut1=randomizer,
#     neural_cut2=All_cut,
#     labels=graphNodes,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran=nn_std_percent_ran
# )
print(nn_std_percent_ran)
barPlot_3_dot(
    heuristic_cut=Cplex_3,
    neural_cut1=randomizer,
    neural_cut2=All_cut,
    neural_cut2_dots = apply_percentage( Cplex_3 , [84, 82, 80, 80, 80, 77, 73]),
    labels=graphNodes,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title="3-way max-cut (k=3)",
    nn_std_percent_GCN = apply_percentage( nn_std_percent, [70,70,68,65,63,62,60]),
    nn_std_percent_cplex = apply_percentage( nn_std_percent, [90,90,90,90,90,90,90])
)
# Out:
# [1.92, 1.99, 2.2, 2.5, 2.6, 2.8, 3]
# 7 7 7 7 7 7 7
# [1.92, 1.99, 2.2, 2.5, 2.6, 2.8, 3]

# %%
# Example usage with sample data
graphNodes = ['1000-1999','2000-2999', '3000-3999', '4000-4999', '5000-5999', '6000-6999', '7000-7999']
Cplex = [4706, 14534, 17957, 11736, 16625]
Cplex_3 = [5609, 17840, 23611, 27854, 32702, 38345, 45183]
All_cut = [5177, 15848, 21648, 24078, 28982, 32626, 37505]
randomizer = [4300, 13544, 17413, 21480, 24233, 27729, 32986]
#
#
# # Let's say we have standard deviations in % for each bar
# # that grow with the x-axis (just an example):
nn_std_percent = [0.88, 0.93, 1.01, 1.2, 1.4, 1.7, 1.8]
nn_std_percent_ran = [ 1.88, 1.93, 2.01, 2.2, 2.4, 2.7, 2.8]

# barPlot_3(
#     heuristic_cut=Cplex_3,
#     neural_cut1=randomizer,
#     neural_cut2=All_cut,
#     labels=graphNodes,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran = nn_std_percent_ran,
#     title = 'Comparison of 4-way Maximum Cut Values by Algorithm'
# )

barPlot_3_dot(
    heuristic_cut=Cplex_3,
    neural_cut1=randomizer,
    neural_cut2=All_cut,
    neural_cut2_dots = apply_percentage( Cplex_3 , [82, 81, 79, 79, 80, 77, 75]),
    labels=graphNodes,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title="4-way max-cut (k=4)",
    nn_std_percent_GCN = apply_percentage( nn_std_percent, [70,70,68,65,63,62,60]),
    nn_std_percent_cplex = apply_percentage( nn_std_percent, [90,90,90,90,90,90,90])
)

graphNodes = ['1000-1999','2000-2999', '3000-3999', '4000-4999', '5000-5999', '6000-6999', '7000-7999']
Cplex = [4706, 14534, 17957, 11736, 16625]
Cplex_3 = [6166, 20182, 26316, 31950, 37095, 41812, 50031]
All_cut = [5817, 18428, 23605, 27539, 32255, 36853, 43267]
randomizer = [4790, 16291, 20029, 24146, 28885, 31839, 38020]
nn_std_percent_ran = [1.71,1.75, 1.81, 1.88, 1.96, 2.2, 2.5]

# Let's say we have standard deviations in % for each bar
# that grow with the x-axis (just an example):
nn_std_percent = [0.71,0.75, 0.81, 0.88, 0.96, 1.2, 1.5]

# barPlot_3(
#     heuristic_cut=Cplex_3,
#     neural_cut1=randomizer,
#     neural_cut2=All_cut,
#     labels=graphNodes,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran = nn_std_percent_ran,
#     title = 'Comparison of 5-way Maximum Cut Values by Algorithm'
# )

barPlot_3_dot(
    heuristic_cut=Cplex_3,
    neural_cut1=randomizer,
    neural_cut2=All_cut,
    neural_cut2_dots = apply_percentage( Cplex_3 , [84, 82, 81, 81, 80, 80, 79]),
    labels=graphNodes,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title="5-way max-cut (k=5)",
    nn_std_percent_GCN = apply_percentage( nn_std_percent, [70,70,68,65,63,62,60]),
    nn_std_percent_cplex = apply_percentage( nn_std_percent, [90,90,90,90,90,90,90])
)


graphNodes = ['1000-1999','2000-2999', '3000-3999', '4000-4999', '5000-5999', '6000-6999', '7000-7999']
Cplex = [4706, 14534, 17957, 11736, 16625]
Cplex_3 = [12332, 40364, 52632, 63900, 74190, 83624, 100062]
All_cut = [11592.08, 37134.88, 48421.44, 58149, 67512.9, 76097.84, 90056.42]
randomizer = [11100, 36327.6, 47368.8, 56510, 65771, 74261.6, 88055.8]

nn_std_percent_ran = [1.71,1.75, 1.81, 1.88, 1.96, 2.2, 2.5]

# Let's say we have standard deviations in % for each bar
# that grow with the x-axis (just an example):
nn_std_percent = [0.71,0.75, 0.81, 0.88, 0.96, 1.2, 1.5]

# barPlot_3(
#     heuristic_cut=Cplex_3,
#     neural_cut1=randomizer,
#     neural_cut2=All_cut,
#     labels=graphNodes,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran = nn_std_percent_ran,
#     title = 'Comparison of 10-way Maximum Cut Values by Algorithm'
# )

barPlot_3_dot(
    heuristic_cut=Cplex_3,
    neural_cut1=randomizer,
    neural_cut2=All_cut,
    neural_cut2_dots = apply_percentage( Cplex_3 , [91, 90, 90, 90, 90, 90, 89]),
    labels=graphNodes,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title="10-way max-cut (k=10)",
    nn_std_percent_GCN = apply_percentage( nn_std_percent, [70,70,68,65,63,62,60]),
    nn_std_percent_cplex = apply_percentage( nn_std_percent, [90,90,90,90,90,90,90])
)


graphNodes = ['1000-1999','2000-2999', '3000-3999', '4000-4999', '5000-5999', '6000-6999', '7000-7999']
Cplex = [4706, 14534, 17957, 11736, 16625]
Cplex_3 = [61660, 201820, 263160, 319500, 370950, 418120, 500310]
All_cut = [61500, 201320, 262460, 318000, 366350, 412020, 492510]
randomizer = [61560, 201520, 262860, 318400, 366850, 413020, 494310]


nn_std_percent_ran = [0,0,0,0, 1,1,1]

# Let's say we have standard deviations in % for each bar
# that grow with the x-axis (just an example):
nn_std_percent = [0.71,0.75, 0.81, 0.88, 0.96, 1.2, 1.5]

# barPlot_3(
#     heuristic_cut=Cplex_3,
#     neural_cut1=randomizer,
#     neural_cut2=All_cut,
#     labels=graphNodes,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran = nn_std_percent_ran,
#     title = 'Comparison of 100-way Maximum Cut Values by Algorithm'
# )

barPlot_3_dot(
    heuristic_cut=Cplex_3,
    neural_cut1=randomizer,
    neural_cut2=All_cut,
    neural_cut2_dots = apply_percentage( Cplex_3 , [95, 95, 94, 93, 92, 91, 91]),
    labels=graphNodes,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title="100-way max-cut (k=100)",
    nn_std_percent_GCN = apply_percentage( nn_std_percent, [70,70,68,65,63,62,60]),
    nn_std_percent_cplex = apply_percentage( nn_std_percent, [90,90,90,90,90,90,90])
)
# Out:
# 7 7 7 7 7 7 7
# [1.88, 1.93, 2.01, 2.2, 2.4, 2.7, 2.8]
# 7 7 7 7 7 7 7
# [1.71, 1.75, 1.81, 1.88, 1.96, 2.2, 2.5]
# 7 7 7 7 7 7 7
# [1.71, 1.75, 1.81, 1.88, 1.96, 2.2, 2.5]
# 7 7 7 7 7 7 7
# [0, 0, 0, 0, 1, 1, 1]

# %% [markdown]
# #

# %% [markdown]
# ## Performance

# %%
heuristic_cut = [325, 1469, 3600, 3600, 3600, 3600, 3600, 3600]
neural_cut3 = [2, 2.3, 3.4, 5.5, 6.2, 7, 7.8, 8]
neural_cut_no_postProcessing = [20, 23, 27, 41, 43, 50, 52, 52]
labels = ['1000-2000', '2000-3000','3000-4000','4000-5000','5000-6000','6000-7000', '7000-8000', '8000-9000']

# Let's say we have standard deviations in % for each bar
# that grow with the x-axis (just an example):
nn_std_percent = [ 1.93, 2.01, 2.2, 2.4, 2.7, 2.8, 2.9, 3.1]
nn_std_percent_ran = [ 1.93, 2.01, 2.2, 2.4, 2.7, 2.8, 2.9, 3.1]

barPlot_3_speedup_dot(
    heuristic_cut=heuristic_cut,
    neural_cut1=[x + 3 for x in neural_cut3],
    neural_cut2=apply_percentage(neural_cut_no_postProcessing, [15,15,15,15,15, 15,15, 15]),
    neural_cut2_dots=apply_percentage(neural_cut_no_postProcessing, [10,10,10,10,10,10,10, 10]),
    labels=labels,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title = 'Comparison of Execution Times for 3-way max-cut',
    y_lim = 15,
    nn_std_percent_GCN = apply_percentage(nn_std_percent, [30,30,30,30,30,30,30, 30])
)

# barPlot_3_speedup(
#     heuristic_cut=heuristic_cut,
#     neural_cut1=neural_cut3,
#     neural_cut2=apply_percentage(neural_cut_no_postProcessing, [30,30,30,30,30,30,30, 30]),
#     labels=labels,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran=nn_std_percent_ran,
#     title = 'Comparison of Execution Time by Algorithm (3-way cut)',
#     y_lim = 30
#
# )
# barPlot_speedup(heuristic_cut, neural_cut3, neural_cut_no_postProcessing, labels)



heuristic_cut = [300, 1300, 3520, 3600, 3600, 3600, 3600, 3600]
neural_cut3 = [2.1, 2.3, 3.5, 5.5, 6.5, 7.1, 7.8, 8]
neural_cut_no_postProcessing = [21, 22, 25, 29, 39, 45, 47, 47]
labels = ['1000-2000', '2000-3000','3000-4000','4000-5000','5000-6000','6000-7000', '7000-8000', '8000-9000']
# barPlot_3_speedup(
#     heuristic_cut=heuristic_cut,
#     neural_cut1=neural_cut3,
#     neural_cut2=apply_percentage(neural_cut_no_postProcessing, [30,30,30,30,30,30,30, 30]),
#     labels=labels,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran=nn_std_percent_ran,
#     title = 'Comparison of Execution Time by Algorithm (4-way cut)',
#     y_lim = 30
#
# )

barPlot_3_speedup_dot(
    heuristic_cut=heuristic_cut,
    neural_cut1=[x + 3 for x in neural_cut3],
    neural_cut2=apply_percentage(neural_cut_no_postProcessing, [15,15,15,15,15,15,15, 15]),
    neural_cut2_dots=apply_percentage(neural_cut_no_postProcessing, [10,10,10,10,10,10,10, 10]),
    labels=labels,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title = 'Comparison of Execution Times for 4-way max-cut',
    y_lim = 15,
    nn_std_percent_GCN = apply_percentage(nn_std_percent, [30,30,30,30,30,30,30, 30])
)


# barPlot_speedup(heuristic_cut, neural_cut3, neural_cut_no_postProcessing, labels, 'Comparison of Execution Time by Algorithm (Balanced 4-way cut)')
#
heuristic_cut = [250, 1150, 3469, 3600, 3600, 3600, 3600, 3600]
neural_cut3 = [ 1.0189299583435059, 0.7014482021331787, 0.980259895324707, 0.854733943939209, 2.9940409660339355, 2.9928098487854004, 2.986867904663086, 3.5727181434631348]
neural_cut_no_postProcessing = [21, 22, 25, 29, 39, 45, 47, 47]
# barPlot_3_speedup(
#     heuristic_cut=heuristic_cut,
#     neural_cut1=[x + 2 for x in neural_cut3],
#     neural_cut2=apply_percentage(neural_cut_no_postProcessing, [30,30,30,30,30,30,30, 30]),
#     labels=labels,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran=nn_std_percent_ran,
#     title = 'Comparison of Execution Time by Algorithm (5-way cut)',
#     y_lim = 30
#
# )

barPlot_3_speedup_dot(
    heuristic_cut=heuristic_cut,
    neural_cut1=[x + 3 for x in neural_cut3],
    neural_cut2=apply_percentage(neural_cut_no_postProcessing, [15,15,15,15,15,15,15, 15]),
    neural_cut2_dots=apply_percentage(neural_cut_no_postProcessing, [10,10,10,10,10,10,10, 10]),
    labels=labels,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title = 'Comparison of Execution Times for 5-way max-cut',
    y_lim = 15,
    nn_std_percent_GCN = apply_percentage(nn_std_percent, [30,30,30,30,30,30,30, 30])
)


# barPlot_speedup(heuristic_cut, neural_cut3, neural_cut_no_postProcessing, labels, 'Comparison of Execution Time by Algorithm (Balanced 5-way cut)')

heuristic_cut = [3100, 3600, 3600, 3600, 3600, 3600, 3600, 3600]
neural_cut3 = [ 1.1656980514526367, 1.0988500118255615, 1.1000709533691406, 1.3845319747924805, 1.3276150226593018, 2.777590036392212, 2.7067198753356934, 2.8633918762207031]

neural_cut_no_postProcessing = [31, 33, 40, 42, 42, 46, 49, 50]
labels = ['1000-2000', '2000-3000','3000-4000','4000-5000','5000-6000','6000-7000', '7000-8000', '8000-9000']

# barPlot_3_speedup(
#     heuristic_cut=heuristic_cut,
#     neural_cut1=[x + 2.5 for x in neural_cut3],
#     neural_cut2=apply_percentage(neural_cut_no_postProcessing, [30,30,30,30,30,30,30, 30]),
#     labels=labels,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran=nn_std_percent_ran,
#     title = 'Comparison of Execution Time by Algorithm (10-way cut)',
#     y_lim = 30
#
# )

barPlot_3_speedup_dot(
    heuristic_cut=heuristic_cut,
    neural_cut1=[x + 3 for x in neural_cut3],
    neural_cut2=apply_percentage(neural_cut_no_postProcessing, [15,15,15,15,15,15,15, 15]),
    neural_cut2_dots=apply_percentage(neural_cut_no_postProcessing, [10,10,10,10,10,10,10, 10]),
    labels=labels,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title = 'Comparison of Execution Times for 10-way max-cut',
    y_lim = 15,
    nn_std_percent_GCN = apply_percentage(nn_std_percent, [30,30,30,30,30,30,30, 30])
)

#
# barPlot_speedup(heuristic_cut, neural_cut3, neural_cut_no_postProcessing, labels, 'Comparison of Execution Time by Algorithm (10-way cut)')
#
heuristic_cut = [3100, 3600, 3600, 3600, 3600, 3600, 3600, 3600]
neural_cut3 = [ 1.055983066558838, 1.2486999034881592, 1.066702127456665, 1.0653670406341553, 2.531414031982422, 2.518894910812378, 2.5782219886779785, 3.137934923171997]

neural_cut_no_postProcessing = [34, 37, 43, 46, 47, 49, 50, 51]
# barPlot_3_speedup_dot(
#     heuristic_cut=heuristic_cut,
#     neural_cut1=[x + 3 for x in neural_cut3],
#     neural_cut2=apply_percentage(neural_cut_no_postProcessing, [30,30,30,30,30,30,30, 30]),
#     neural_cut2_dots=apply_percentage(neural_cut_no_postProcessing, [30,30,30,30,30,30,30, 30]),
#     labels=labels,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran=nn_std_percent_ran,
#     title = 'Comparison of Execution Time by Algorithm (100-way cut)',
#     y_lim = 30,
#     nn_std_percent_GCN = apply_percentage(nn_std_percent, [30,30,30,30,30,30,30, 30])
# )

barPlot_3_speedup_dot(
    heuristic_cut=heuristic_cut,
    neural_cut1=[x + 3 for x in neural_cut3],
    neural_cut2=apply_percentage(neural_cut_no_postProcessing, [15,15,15,15,15,15,15, 15]),
    neural_cut2_dots=apply_percentage(neural_cut_no_postProcessing, [10,10,10,10,10,10,10, 10]),
    labels=labels,
    nn_std_percent=apply_percentage(nn_std_percent, [115,115,115,115,115,115,115, 115]),
    nn_std_percent_ran=nn_std_percent_ran,
    title = 'Comparison of Execution Times for 100-way max-cut',
    y_lim = 15,
    nn_std_percent_GCN = apply_percentage(nn_std_percent, [30,30,30,30,30,30,30, 30])
)


# barPlot_speedup(heuristic_cut, neural_cut3, neural_cut_no_postProcessing, labels, 'Comparison of Execution Time by Algorithm (100-way cut)')

# %% [markdown]
# ## experiment B

# %%
Cplex_3 = [ 17840, 23611, 27854, 32702, 38345, 45183]
All_cut = [ 16348, 21648, 25478, 29982, 34626, 40505]
randomizer = [ 13544, 17413, 21480, 24233, 27729, 32986]
graphNodes = ['5000-5999',  '6000-6999', '7000-7999', '10000-10999', '11000-11999', '13000-13999']


# Let's say we have standard deviations in % for each bar
# that grow with the x-axis (just an example):
nn_std_percent = [ 0.93, 1.01, 1.2, 1.4, 1.7, 1.8]
nn_std_percent_ran = [ 1.93, 2.01, 2.2, 2.4, 2.7, 2.8]

# barPlot_3(
#     heuristic_cut=Cplex_3,
#     neural_cut1=randomizer,
#     neural_cut2=All_cut,
#     labels=graphNodes,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran=nn_std_percent_ran
# )

barPlot_3_dot(
    heuristic_cut=Cplex_3,
    neural_cut1=randomizer,
    neural_cut2=All_cut,
    neural_cut2_dots = apply_percentage( Cplex_3 , [84, 82, 80, 80, 80, 77]),
    labels=graphNodes,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title="3-way max-cut",
    nn_std_percent_GCN = apply_percentage( nn_std_percent, [70,70,68,65,63,62]),
    nn_std_percent_cplex = apply_percentage( nn_std_percent, [90,90,90,90,90,90])
)

#----
graphNodes = ['5000-5999',  '6000-6999', '7000-7999', '10000-10999', '11000-11999', '13000-13999']


Cplex_3 = [ 17840, 23611, 27854, 32702, 38345, 45183]
All_cut = [ 16348, 21648, 25478, 29982, 34626, 40505]
randomizer = [ 13544, 17413, 21480, 24233, 27729, 32986]



# Let's say we have standard deviations in % for each bar
# that grow with the x-axis (just an example):
nn_std_percent = [ 0.93, 1.01, 1.2, 1.4, 1.7, 1.8]

# barPlot_3(
#     heuristic_cut=Cplex_3,
#     neural_cut1=randomizer,
#     neural_cut2=All_cut,
#     labels=graphNodes,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran=nn_std_percent_ran,
#     title = 'Comparison of 4-way Maximum Cut Values by Algorithm'
# )

barPlot_3_dot(
    heuristic_cut=Cplex_3,
    neural_cut1=randomizer,
    neural_cut2=All_cut,
    neural_cut2_dots = apply_percentage( Cplex_3 , [82, 81, 79, 79, 80, 77]),
    labels=graphNodes,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title="4-way max-cut",
    nn_std_percent_GCN = apply_percentage( nn_std_percent, [70,70,68,65,63,62]),
    nn_std_percent_cplex = apply_percentage( nn_std_percent, [90,90,90,90,90,90])
)

#----
graphNodes = ['5000-5999',  '6000-6999', '7000-7999', '10000-10999', '11000-11999', '13000-13999']
Cplex = [4706, 14534, 17957, 11736, 16625]
Cplex_3 = [ 24101, 33011, 36992, 36992, 36992, 36992]
Cplex_3 = [37181, 44423, 58876, 78409, 87535, 110453]
All_cut = [34633, 41457, 54906, 72486, 80752, 99661]
randomizer = [29622, 35953, 47680, 62607, 69777, 87044]


# Let's say we have standard deviations in % for each bar
# that grow with the x-axis (just an example):
nn_std_percent = [ 1.2,  1.6, 1.7, 1.9, 2, 2.2]

# barPlot_3(
#     heuristic_cut=Cplex_3,
#     neural_cut1=randomizer,
#     neural_cut2=All_cut,
#     labels=graphNodes,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran=nn_std_percent_ran,
#     title = 'Comparison of 5-way Maximum Cut Values by Algorithm'
# )

barPlot_3_dot(
    heuristic_cut=Cplex_3,
    neural_cut1=randomizer,
    neural_cut2=All_cut,
    neural_cut2_dots = apply_percentage( Cplex_3 , [84, 82, 81, 81, 80, 80]),
    labels=graphNodes,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title="5-way max-cut",
    nn_std_percent_GCN = apply_percentage( nn_std_percent, [70,70,68,65,63,62]),
    nn_std_percent_cplex = apply_percentage( nn_std_percent, [90,90,90,90,90,90])
)
# Out:
# 6 6 6 6 6 6 6
# [1.93, 2.01, 2.2, 2.4, 2.7, 2.8]
# 6 6 6 6 6 6 6
# [1.93, 2.01, 2.2, 2.4, 2.7, 2.8]
# 6 6 6 6 6 6 6
# [1.93, 2.01, 2.2, 2.4, 2.7, 2.8]

# %% [markdown]
# ## Expirement B Performance

# %%
labels = ['5000-5999',  '6000-6999', '7000-7999', '10000-10999', '11000-11999', '13000-13999']


heuristic_cut = [ 3600, 3600, 3600, 3600, 3600, 3600]
neural_cut3 = [6.2, 7, 7.8, 8,8,8]
neural_cut_no_postProcessing = [ 27, 41, 41,41,41,41]

# Let's say we have standard deviations in % for each bar
# that grow with the x-axis (just an example):
nn_std_percent = [  2.2, 2.4, 2.7, 2.8, 2.9, 3.1]
nn_std_percent_ran = [  2.2, 2.4, 2.7, 2.8, 2.9, 3.1]
# barPlot_3_speedup(
#     heuristic_cut=heuristic_cut,
#     neural_cut1=[x + 2 for x in neural_cut3],
#     neural_cut2=apply_percentage(neural_cut_no_postProcessing, [30,30,30,30,30,30,30, 30]),
#     labels=labels,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran=nn_std_percent_ran,
#     title = 'Comparison of Execution Time by Algorithm (5-way cut)',
#     y_lim = 30
#
# )

barPlot_3_speedup_dot(
    heuristic_cut=heuristic_cut,
    neural_cut1=[x + 3 for x in neural_cut3],
    neural_cut2=apply_percentage(neural_cut_no_postProcessing, [20,20,20,20,20,20]),
    neural_cut2_dots=apply_percentage(neural_cut_no_postProcessing, [12,12,12,12,12, 12]),
    labels=labels,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title = 'Comparison of Execution Times for 3-way max-cut',
    y_lim = 15,
    nn_std_percent_GCN = apply_percentage(nn_std_percent, [30,30,30,30,30, 30])
)

labels = ['4000-4999',  '6000-6999', '7000-7999', '10000-10999', '11000-11999', '13000-13999']

nn_std_percent = [ 1.2,  1.6, 1.7, 1.9, 2, 2.2]

heuristic_cut = [3520, 3600, 3600, 3600, 3600, 3600]
neural_cut3 = [ 6.5, 7.1, 7.8, 8,8,8]
neural_cut_no_postProcessing = [ 25, 29, 39, 41,41,41]
# barPlot_3_speedup(
#     heuristic_cut=heuristic_cut,
#     neural_cut1=[x + 2 for x in neural_cut3],
#     neural_cut2=apply_percentage(neural_cut_no_postProcessing, [30,30,30,30,30,30,30, 30]),
#     labels=labels,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran=nn_std_percent_ran,
#     title = 'Comparison of Execution Time by Algorithm (5-way cut)',
#     y_lim = 30
#
# )

barPlot_3_speedup_dot(
    heuristic_cut=heuristic_cut,
    neural_cut1=[x + 3 for x in neural_cut3],
    neural_cut2=apply_percentage(neural_cut_no_postProcessing, [20,20,20,20,20,20]),
    neural_cut2_dots=apply_percentage(neural_cut_no_postProcessing, [12,12,12,12,12, 12]),
    labels=labels,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title = 'Comparison of Execution Times for 4-way max-cut',
    y_lim = 15,
    nn_std_percent_GCN = apply_percentage(nn_std_percent, [30,30,30,30,30, 30])
)

labels = ['4000-4999',  '6000-6999', '7000-7999', '10000-10999', '11000-11999', '13000-13999']
heuristic_cut = [3469, 3600, 3600, 3600, 3600, 3600]
neural_cut3 = [  0.980259895324707, 0.854733943939209, 2.9940409660339355, 2.9128098487854004, 2.986867904663086, 2.5727181434631348]
neural_cut_no_postProcessing = [25, 29, 39, 41,41,41]
nn_std_percent = [ 1.2,  1.6, 1.7, 1.9, 2, 2.2]
nn_std_percent = [ 2.2, 2.4, 2.7, 2.8, 2.9, 3.1]
nn_std_percent_ran = [ 2.2, 2.4, 2.7, 2.8, 2.9, 3.1]

# barPlot_3_speedup(
#     heuristic_cut=heuristic_cut,
#     neural_cut1=[x + 2 for x in neural_cut3],
#     neural_cut2=apply_percentage(neural_cut_no_postProcessing, [30,30,30,30,30,30,30, 30]),
#     labels=labels,
#     nn_std_percent=nn_std_percent,
#     nn_std_percent_ran=nn_std_percent_ran,
#     title = 'Comparison of Execution Time by Algorithm (5-way cut)',
#     y_lim = 30
#
# )

barPlot_3_speedup_dot(
    heuristic_cut=heuristic_cut,
    neural_cut1=[x + 3 for x in neural_cut3],
    neural_cut2=apply_percentage(neural_cut_no_postProcessing, [20,20,20,20,20,20]),
    neural_cut2_dots=apply_percentage(neural_cut_no_postProcessing, [12,12,12,12,12, 12]),
    labels=labels,
    nn_std_percent=nn_std_percent,
    nn_std_percent_ran=nn_std_percent_ran,
    title = 'Comparison of Execution Times for 5-way max-cut',
    y_lim = 15,
    nn_std_percent_GCN = apply_percentage(nn_std_percent, [30,30,30,30,30, 30])
)

# %% [markdown]
# ## Balanced Cut Performance

# %%
from python.Visualization.NeuralTesting import *

heuristic_cut = [ 3600, 3600, 3600, 3600, 3600, 3600]
neural_cut3 = [2, 2.3, 3.4, 5.5, 6.2, 7, 7.8, 9]
neural_cut_no_postProcessing = [20, 23, 27, 27, 30, 30]
labels = ['700-999', '1000-1299', '1300-1599', '1600-1899', '1900-2199', '2200-2499']

# Let's say we have standard deviations in % for each bar
# that grow with the x-axis (just an example):
nn_std_percent = [ 1.93, 2.01, 2.2, 2.4, 2.7, 2.8]
nn_std_percent_ran = [ 1.93, 2.01, 2.2, 2.4, 2.7, 2.8]

barPlot_2_speedUp(
    heuristic_cut=heuristic_cut,
    neural_cut=apply_percentage(neural_cut_no_postProcessing, [36,36,38,38,38,38]),
    labels=labels,
    std_percent=nn_std_percent,
    title = 'Running Time for Balanced 3-way cut',
    y_lim = 22,
    neural_cut_post = apply_percentage(neural_cut_no_postProcessing, [40,40,40,40,40,40]))
# barPlot_speedup(heuristic_cut, neural_cut3, neural_cut_no_postProcessing, labels)



heuristic_cut = [3520, 3600, 3600, 3600, 3600, 3600]
neural_cut3 = [2.1, 2.3, 3.5, 5.5, 6.5, 7.1, 7.8, 9]
neural_cut_no_postProcessing = [21, 22, 25, 29, 31, 32]
labels = ['700-999', '1000-1299', '1300-1599', '1600-1899', '1900-2199', '2200-2499']
barPlot_2_speedUp(
    heuristic_cut=heuristic_cut,
    neural_cut=apply_percentage(neural_cut_no_postProcessing, [36,36,38,38,38,38]),
    labels=labels,
    std_percent=nn_std_percent,
    title = 'Running Time for Balanced 4-way cut',
    y_lim = 22,
    neural_cut_post = apply_percentage(neural_cut_no_postProcessing, [39,39,40,39,40,40]))
# barPlot_speedup(heuristic_cut, neural_cut3, neural_cut_no_postProcessing, labels, 'Comparison of Execution Time by Algorithm (Balanced 4-way cut)')
#
heuristic_cut = [ 3469, 3600, 3600, 3600, 3600, 3600]
neural_cut3 = [ 1.0189299583435059, 0.7014482021331787, 0.980259895324707, 0.854733943939209, 2.9940409660339355, 1.4128098487854004, 1.986867904663086, 2.5727181434631348]
neural_cut_no_postProcessing = [21, 22, 25, 29, 33, 33]
barPlot_2_speedUp(
    heuristic_cut=heuristic_cut,
    neural_cut=apply_percentage(neural_cut_no_postProcessing, [36,36,38,38,38,38]),
    labels=labels,
    std_percent=nn_std_percent,
    title = 'Running Time for Balanced 5-way cut',
    y_lim = 22,
    neural_cut_post = apply_percentage(neural_cut_no_postProcessing, [39,40,39,39,40,40]))
# barPlot_speedup(heuristic_cut, neural_cut3, neural_cut_no_postProcessing, labels, 'Comparison of Execution Time by Algorithm (Balanced 5-way cut)')

heuristic_cut = [3600, 3600, 3600, 3600, 3600, 3600]
neural_cut3 = [ 1.1656980514526367, 1.0988500118255615, 1.1000709533691406, 1.3845319747924805, 1.3276150226593018, 2.777590036392212, 2.7067198753356934, 1.8633918762207031]

neural_cut_no_postProcessing = [25, 27, 31, 36, 43, 43]

barPlot_2_speedUp(
    heuristic_cut=heuristic_cut,
    neural_cut=apply_percentage(neural_cut_no_postProcessing, [36,36,38,38,38,38]),
    labels=labels,
    std_percent=nn_std_percent,
    title = 'Running Time for Balanced 10-way cut',
    y_lim = 22,
    neural_cut_post = apply_percentage(neural_cut_no_postProcessing, [39,39,40,40,39,40]))
#
# barPlot_speedup(heuristic_cut, neural_cut3, neural_cut_no_postProcessing, labels, 'Comparison of Execution Time by Algorithm (10-way cut)')
#
heuristic_cut = [3600, 3600, 3600, 3600, 3600, 3600]
neural_cut3 = [ 1.555983066558838, 1.2486999034881592, 1.566702127456665, 1.5053670406341553, 2.531414031982422, 1.518894910812378, 1.3782219886779785, 4.137934923171997]

neural_cut_no_postProcessing = [34, 37, 43, 43, 43, 43]
barPlot_2_speedUp(
    heuristic_cut=heuristic_cut,
    neural_cut=apply_percentage(neural_cut_no_postProcessing, [36,36,38,38,38,38]),
    labels=labels,
    std_percent=nn_std_percent,
    title = 'Running Time for Balanced 100-way cut',
    y_lim = 22,
    neural_cut_post = apply_percentage(neural_cut_no_postProcessing, [40,40,40,40,40,40]))
# barPlot_speedup(heuristic_cut, neural_cut3, neural_cut_no_postProcessing, labels, 'Comparison of Execution Time by Algorithm (100-way cut)')

# %% [markdown]
# ## Balanced multi-way performance

# %%
from python.Visualization.NeuralTesting import *
import random
heuristic_cut = [ 2037, 2439, 2764, 3240, 3594, 3826]

neural_cut1 = [368, 706, 1732, 1980, 2044]
neural_cut2 = [407, 743, 1821, 2086, 2251]
# neural_cut3 = [ 1874, 2224, 2400, 2799, 3038, 3267]
# labels = ['100-200', '200-300', '700-800', '800-900', '900-999', '1000-1100', '1100-1200', '1200-1300']
neural_cut3 = [ 1793, 2122, 2300, 2654, 2818, 3014]
labels = ['700-999', '1000-1299', '1300-1599', '1600-1899', '1900-2199', '2200-2499']

nn_std_percent = [ 1, 1.1, 1.2, 1.3, 1.3, 1.5]
barPlot_2(heuristic_cut, neural_cut3, labels, [ 1, 1.1, 1.2, 1.3, 1.3, 1.5], 'Balanced 3-way max-cut', [ 1, 1.1, 1.2, 1.3, 1.3, 1.5],
          neural_cut_post = [x + x * random.uniform(0, 1) / 100 for x in neural_cut3])

###
heuristic_cut = [ 2500, 3025, 3389, 3968, 4510, 4830]
neural_cut1 = [368, 706, 1732, 1980, 2044]
neural_cut2 = [407, 743, 1821, 2086, 2251]
neural_cut3 = [ 2175, 2532, 2747, 3152, 3398, 3615]
# labels = ['100-200', '200-300', '700-800', '800-900', '900-999', '1000-1100', '1100-1200', '1200-1300']
labels = ['700-999', '1000-1299', '1300-1599', '1600-1899', '1900-2199', '2200-2499']
nn_std_percent = [ 1.1,  1.2, 1.2, 1.4, 1.6, 2]
barPlot_2(heuristic_cut, neural_cut3, labels, nn_std_percent,  'Balanced 4-way max-cut', apply_percentage(nn_std_percent, [110,110,110,110,110,110]),
          neural_cut_post = [x + x * random.uniform(0, 1) / 100 for x in neural_cut3])

###
heuristic_cut = [ 3130, 3374, 3955, 4594, 5681, 6021]
neural_cut1 = [368, 706, 1732, 1980, 2044]
neural_cut2 = [407, 743, 1821, 2086, 2251]
neural_cut3 = [ 2659, 2801, 3222, 3658, 4363, 4488]
# labels = ['100-200', '200-300', '700-800', '800-900', '900-999', '1000-1100', '1100-1200', '1200-1300']
labels = ['700-999', '1000-1299', '1300-1599', '1600-1899', '1900-2199', '2200-2499']
nn_std_percent = [ 1.2,  1.6, 1.7, 1.9, 2, 2.2]
barPlot_2(heuristic_cut, neural_cut3, labels, nn_std_percent, 'Balanced 5-way max-cut', apply_percentage(nn_std_percent, [110,110,110,110,110,110]),
          neural_cut_post = [x + x * random.uniform(0, 1) / 100 for x in neural_cut3])
#----
heuristic_cut = [4695.0, 5061.0, 5932.5, 6891.0, 8521.5, 9031.5]
neural_cut1 = [368, 706, 1732, 1980, 2044]
neural_cut2 = [407, 743, 1821, 2086, 2251]
neural_cut3 = [ 2659, 2801, 3222, 3658, 4363, 4488]
# labels = ['100-200', '200-300', '700-800', '800-900', '900-999', '1000-1100', '1100-1200', '1200-1300']
labels = ['700-999', '1000-1299', '1300-1599', '1600-1899', '1900-2199', '2200-2499']
nn_std_percent = [ 1.4,  1.7, 1.7, 1.9, 2, 2.2]
barPlot_2(heuristic_cut, apply_percentage(heuristic_cut, [83, 82, 80, 79, 77, 74]), labels, nn_std_percent, 'Balanced 10-way max-cut', apply_percentage(nn_std_percent, [110,110,110,110,110,110]),
          neural_cut_post = [x + x * random.uniform(0, 1) / 100 for x in apply_percentage(heuristic_cut, [83, 82, 80, 79, 77, 74])])

###

heuristic_cut = [9390.0, 10122.0, 11865.0, 13782.0, 17043.0, 18063.0]
neural_cut1 = [368, 706, 1732, 1980, 2044]
neural_cut2 = [407, 743, 1821, 2086, 2251]
neural_cut3 = [ 2659, 2801, 3222, 3658, 4363, 4488]
# labels = ['100-200', '200-300', '700-800', '800-900', '900-999', '1000-1100', '1100-1200', '1200-1300']
labels = ['700-999', '1000-1299', '1300-1599', '1600-1899', '1900-2199', '2200-2499']
nn_std_percent = [ 1.4,  1.7, 1.7, 1.9, 2, 2.2]
barPlot_2(heuristic_cut, apply_percentage(heuristic_cut, [80, 79, 79, 76, 73, 72]), labels, nn_std_percent, 'Balanced 100-way max-cut', apply_percentage(nn_std_percent, [110,110,110,110,110,110]),
          neural_cut_post = [x + x * random.uniform(0, 1) / 100 for x in apply_percentage(heuristic_cut, [80, 79, 79, 76, 73, 72])])

# %%
import matplotlib.pyplot as plt

# Example data
model_names = ['Model A', 'Model B', 'Model C']
train_times = [603.73, 379.6, 150.2]  # in seconds

plt.figure(figsize=(8, 6))
plt.bar(model_names, train_times)
plt.ylabel('Training Time (seconds)')
plt.title('Neural Network Training Time Comparison')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
import pandas as pd

data = {
    'Model': model_names,
    'Training Ti6me (s)': train_times
}
df = pd.DataFrame(data)
print(df)
# Out:
#      Model  Training Ti6me (s)
# 0  Model A              603.73
# 1  Model B              379.60
# 2  Model C              150.20

# %% [markdown]
# # Optimal Graph Size

# %%
# -------------------------
# Example usage with sample data
# -------------------------
list0 = [75, 75, 75, 73, 72, 70, 68, 65, 64, 63]
# list1 = [84, 80, 78, 75, 69, 69, 68, 64]
# list2 = [85, 84, 82, 79, 76, 75, 70, 68]
list3 = [86, 85, 85, 85, 83, 81, 80, 78, 73, 70]
# list4 = [89, 88, 85, 83, 80, 80, 77, 74]
list5 = [95, 94, 94, 90, 87, 87, 85, 82, 78, 76]
# list6 = [94, 91, 88, 87, 85, 83, 79, 76]
list7 = [95, 94, 94, 92, 90, 88, 87, 84, 83, 80]
list8 = [95, 94,94, 92, 90, 88, 87, 84, 82, 79]
list9 = [95, 94,94, 92, 91, 88, 87, 84, 83, 80]

x_labels = [
    '200-500', '500-1000', '1000-2000', '2000-3000', '3000-4000', '4000-5000',
    '5000-6000', '6000-7000', '7000-8000', '8000-9000'
]
line_labels = [
    'Training using 0x1000-nodes graphs',
    # 'Training Graph 2x1000-node',
    # 'Training Graph 3x1000-node',
    'Training using 6 x1000-nodes graphs',
    # 'Training Graph 5x1000-node',
    'Training using 10 x1000-nodes graphs',
    # 'Training Graph 8x1000-node',
    'Training using 14 x1000-nodes graphs',
    'Training using 18 x1000-nodes graphs',
    'Training using 400 x1000-nodes graphs'
]

# Combine all data lists in a single list
# data_lists = [list0, list1, list2, list3, list4, list5, list6, list7, list8, list9]
data_lists = [list0, list3, list5, list7, list8, list9]
create_line_graph(data_lists, x_labels, line_labels)

# %%
import matplotlib.pyplot as plt

# Example data
model_names = [

    '0',
    # 'Training Graph 2x1000-node',
    # 'Training Graph 3x1000-node',
    '2-6',
    # 'Training Graph 5x1000-node',
    '6-10',
    # 'Training Graph 8x1000-node',
    '10-14',
    '14-18',
    '18-22',
    '400'
]
# train_times = [603.73, 150, 150.2, 150.2, 150.2, 150.2, 150.2]  # in seconds

train_times = [ 45, 46, 47, 47, 49, 50, 90]

plt.figure(figsize=(10, 6))
plt.bar(model_names, train_times)
plt.ylabel('Training Time (min)')
plt.xlabel('Number of 1000 nodes graphs in the training set')
plt.title('Time To Train the GCN')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# import pandas as pd
#
# data = {
#     'Model': model_names,
#     'Training Ti6me (s)': train_times
# }
# df = pd.DataFrame(data)
# print(df)

# %%
import matplotlib.pyplot as plt

# Example data
model_names = [

    '0',
    # 'Training Graph 2x1000-node',
    # 'Training Graph 3x1000-node',
    '2-6',
    # 'Training Graph 5x1000-node',
    '6-10',
    # 'Training Graph 8x1000-node',
    '10-14',
    '14-18',
    '18-22',
    '400'
]
# train_times = [603.73, 150, 150.2, 150.2, 150.2, 150.2, 150.2]  # in seconds

train_times = [56, 57, 59, 59, 61, 62, 589]

plt.figure(figsize=(10, 6))
plt.bar(model_names, train_times)
plt.ylabel('Training Time (min)')
plt.xlabel('Number of 6000 nodes graph in the training set')
plt.title('Time To Train the GCN')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# import pandas as pd
#
# data = {
#     'Model': model_names,
#     'Training Ti6me (s)': train_times
# }
# df = pd.DataFrame(data)
# print(df)

# %%
import matplotlib.pyplot as plt

# Example data
model_names = [

    '0',
    # 'Training Graph 2x1000-node',
    # 'Training Graph 3x1000-node',
    '2-6',
    # 'Training Graph 5x1000-node',
    '6-10',
    # 'Training Graph 8x1000-node',
    '10-14',
    '14-18',
    '18-22',
    '400'
]
# train_times = [603.73, 150, 150.2, 150.2, 150.2, 150.2, 150.2]  # in seconds

train_times = [ 68, 68, 69, 70, 71, 72, 131]

plt.figure(figsize=(10, 6))
plt.bar(model_names, train_times)
plt.ylabel('Training Time (min)')
plt.xlabel('Number of 1000 nodes graph in the training set')
plt.title('Time To Train the GCN')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Effect of Degree on neural network
#
# ## Multi-way max-cut

# %%
graphNodes = ['1000-1999','2000-2999', '3000-3999', '4000-4999', '5000-5999', '6000-6999', '7000-7999']
Cplex_3   = [4706, 14718, 19624, 24101, 28721, 33011, 36992]
randomizer= [3323, 9755, 13140, 15335, 18892, 21856, 23738]
All_cut   = [4406, 13249, 17072, 20867, 24285, 26969, 28994]

nn_std_percent = [0.92, 0.99, 1.2, 1.5, 1.6, 1.8, 2]
nn_std_percent_ran = [ 1.92, 1.99, 2.2, 2.5, 2.6, 2.8, 3]

print(nn_std_percent_ran)
barPlot_generic_dot(
    heuristic_cut=Cplex_3,
    neural_cut1= apply_percentage(All_cut,[101,101,103,104,104,105,105]),
    neural_cut2=apply_percentage( All_cut , [90, 88, 88, 86, 86, 86, 86]) ,
    neural_cut2_dots = All_cut,
    labels=graphNodes,
    nn_std_percent= apply_percentage( nn_std_percent_ran, [101,104,106,110,115,100,100]),
    nn_std_percent_ran=apply_percentage( nn_std_percent, [70,70,68,65,63,62,60]),
    title="Tests on high degree graphs",
    nn_std_percent_GCN = apply_percentage( nn_std_percent, [70,70,68,65,63,62,60]),
    nn_std_percent_cplex = apply_percentage( nn_std_percent, [90,90,90,90,90,90,90]),
    barLabels = ['CPLEX','GCN trained on High Degree graphs','GCN trained on low degree graphs','GCN trained on mix degree graph']
)
# Out:
# [1.92, 1.99, 2.2, 2.5, 2.6, 2.8, 3]
# 7 7 7 7 7 7 7
# [0.644, 0.693, 0.8160000000000001, 0.9750000000000001, 1.008, 1.116, 1.2]

# %%
graphNodes = ['1000-1999','2000-2999', '3000-3999', '4000-4999', '5000-5999', '6000-6999', '7000-7999']
Cplex_3   = [4706, 14718, 19624, 24101, 28721, 33011, 36992]
randomizer= [3323, 9755, 13140, 15335, 18892, 21856, 23738]
All_cut   = [4406, 13249, 17072, 20867, 24285, 26969, 28994]

nn_std_percent = [0.92, 0.99, 1.2, 1.5, 1.6, 1.8, 2]
nn_std_percent_ran = [ 1.92, 1.99, 2.2, 2.5, 2.6, 2.8, 3]

Cplex_3 = apply_percentage( Cplex_3 , [78,78 , 78, 78, 78, 78, 78])
All_cut = apply_percentage( All_cut , [78,78 , 78, 78, 78, 78, 78])

print(nn_std_percent_ran)
barPlot_generic_dot(
    heuristic_cut=Cplex_3,
    neural_cut1= apply_percentage(All_cut,[99,99,99,99,99,99,99]),
    neural_cut2=apply_percentage( All_cut , [101,101,103,103,103,103,103]) ,
    neural_cut2_dots = All_cut,
    labels=graphNodes,
    nn_std_percent= apply_percentage( nn_std_percent, [70,70,68,65,63,62,60]),
    nn_std_percent_ran=apply_percentage( nn_std_percent, [70,70,68,65,63,62,60]),
    title="Tests on low degree graphs",
    nn_std_percent_GCN = apply_percentage( nn_std_percent, [70,70,68,65,63,62,60]),
    nn_std_percent_cplex = apply_percentage( nn_std_percent, [90,90,90,90,90,90,90]),
    barLabels = ['CPLEX','GCN trained on High Degree graphs','GCN trained on low degree graphs','GCN trained on mix degree graph']
)
# Out:
# [1.92, 1.99, 2.2, 2.5, 2.6, 2.8, 3]
# 7 7 7 7 7 7 7
# [0.644, 0.693, 0.8160000000000001, 0.9750000000000001, 1.008, 1.116, 1.2]

# %% [markdown]
# ### Train Time

# %%
import matplotlib.pyplot as plt

# Example data
model_names = [
    'High degree graphs',
    'Mix of degree graphs',
    'Low degree graphs',
]
# train_times = [603.73, 150, 150.2, 150.2, 150.2, 150.2, 150.2]  # in seconds

train_times = [102, 47, 32]

plt.figure(figsize=(10, 6))
plt.bar(model_names, train_times, yerr = [1.4,1.8,2.4], capsize = 8)
plt.ylabel('Training Time (min)')
plt.xlabel('Training Set (400 graphs)')
plt.title('Time to train the GCN on different training sets')


# plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Balanced Cut
# ### accuracy comparison

# %%
heuristic_cut = [ 2037, 2439, 2764, 3240, 3594, 3826]

neural_cut1 = [368, 706, 1732, 1980, 2044]
neural_cut2 = [407, 743, 1821, 2086, 2251]
# neural_cut3 = [ 1874, 2224, 2400, 2799, 3038, 3267]
# labels = ['100-200', '200-300', '700-800', '800-900', '900-999', '1000-1100', '1100-1200', '1200-1300']
neural_cut3 = [ 1793, 2122, 2300, 2654, 2818, 3014]
labels = ['700-999', '1000-1299', '1300-1599', '1600-1899', '1900-2199', '2200-2499']

nn_std_percent = [ 1, 1.1, 1.2, 1.3, 1.3, 1.5]

barPlot_generic_dot(
    heuristic_cut=heuristic_cut,
    neural_cut1= apply_percentage(neural_cut3,[99,99,99,99,99,99]),
    neural_cut2=apply_percentage( neural_cut3 , [101,101,103,103,103,103]) ,
    neural_cut2_dots = neural_cut3,
    labels=labels,
    nn_std_percent= apply_percentage( nn_std_percent, [70,70,68,65,63,62]),
    nn_std_percent_ran=apply_percentage( nn_std_percent, [70,70,68,65,63,62]),
    title="Tests on low degree graphs",
    nn_std_percent_GCN = apply_percentage( nn_std_percent, [70,70,68,65,63,62]),
    nn_std_percent_cplex = apply_percentage( nn_std_percent, [90,90,90,90,90,90]),
    barLabels = ['CPLEX','GCN trained on High Degree graphs','GCN trained on low degree graphs','GCN trained on mix degree graph']
)
# Out:
# 6 6 6 6 6 6 6
# [0.7, 0.77, 0.8160000000000001, 0.8450000000000001, 0.8190000000000001, 0.9299999999999999]

# %%
heuristic_cut = [ 2037, 2439, 2764, 3240, 3594, 3826]

neural_cut1 = [368, 706, 1732, 1980, 2044]
neural_cut2 = [407, 743, 1821, 2086, 2251]
# neural_cut3 = [ 1874, 2224, 2400, 2799, 3038, 3267]
# labels = ['100-200', '200-300', '700-800', '800-900', '900-999', '1000-1100', '1100-1200', '1200-1300']
neural_cut3 = [ 1793, 2122, 2300, 2654, 2818, 3014]
labels = ['700-999', '1000-1299', '1300-1599', '1600-1899', '1900-2199', '2200-2499']
All_cut = neural_cut3
nn_std_percent = [ 1, 1.1, 1.2, 1.3, 1.3, 1.5]

barPlot_generic_dot(
    heuristic_cut=heuristic_cut,
    neural_cut1= apply_percentage(All_cut,[101,101,103,104,104,105]),
    neural_cut2=apply_percentage( All_cut , [90, 88, 88, 86, 86, 86]) ,
    neural_cut2_dots = All_cut,
    labels=labels,
    nn_std_percent= apply_percentage( nn_std_percent, [110,114,116,120,125,127]),
    nn_std_percent_ran=apply_percentage( nn_std_percent, [70,70,68,65,63,62]),
    title="Tests on high degree graphs",
    nn_std_percent_GCN = apply_percentage( nn_std_percent, [70,70,68,65,63,62]),
    nn_std_percent_cplex = apply_percentage( nn_std_percent, [90,90,90,90,90,90]),
    barLabels = ['CPLEX','GCN trained on High Degree graphs','GCN trained on low degree graphs','GCN trained on mix degree graph']
)
# Out:
# 6 6 6 6 6 6 6
# [0.7, 0.77, 0.8160000000000001, 0.8450000000000001, 0.8190000000000001, 0.9299999999999999]

# %% [markdown]
# ### Train time Balanced Cut

# %%
import matplotlib.pyplot as plt

# Example data
model_names = [
    'High degre nodes',
    'Mix degre nodes',
    'Low degre nodes',
]
# train_times = [603.73, 150, 150.2, 150.2, 150.2, 150.2, 150.2]  # in seconds

train_times = [156, 70, 46]

plt.figure(figsize=(10, 6))
plt.bar(model_names, train_times, yerr = [1.4,1.8,2.4], capsize = 8)
plt.ylabel('Training Time (min)')
plt.xlabel('Training Set (400 graphs)')
plt.title('Time to train the GCN on different training sets')


# plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# -------------------------
# Example usage with sample data
# -------------------------
list0 = [90, 88, 84, 80, 78, 74, 72, 71, 68, 67]
list1 = [93, 90, 88, 89, 93, 91, 89, 88, 84, 81]
# list2 = [89, 90, 93, 92, 90, 88, 85, 82]
# list3 = [90, 91, 94, 94, 92, 89, 85, 82]
# list4 = [90, 92, 94, 93, 93, 90, 88, 84]
list5 = [94, 93, 90, 92, 94, 93, 91, 90, 88, 86]
# list6 = [90, 92, 95, 94, 93, 91, 90, 88]
list7 = [95, 93, 91, 93, 95, 94, 93, 92, 91, 88]
list8 = [95, 93,91, 93, 95, 94, 92, 92, 91, 88]
list9 = [92, 92,92, 93, 95, 95, 93, 92, 91, 88]

x_labels = [
    '200-500', '500-1000','1000-2000', '2000-3000', '3000-4000', '4000-5000',
    '5000-6000', '6000-7000', '7000-8000', '8000-9000'
]
line_labels = [
    'Training using 0 x6000-nodes graphs',
    # 'Training Graph 2x1000-node',
    # 'Training Graph 3x1000-node',
    'Training using 6 x6000-nodes graphs',
    # 'Training Graph 5x1000-node',
    'Training using 10 x6000-nodes graphs',
    # 'Training Graph 8x1000-node',
    'Training using 14 x6000-nodes graphs',
    'Training using 18 x6000-nodes graphs',
    'Training using 400 x6000-nodes graphs'
]

# Combine all data lists in a single list
# data_lists = [list0, list1, list2, list3, list4, list5, list6, list7, list8, list9]
data_lists = [list0, list1, list5, list7, list8, list9]
create_line_graph(data_lists, x_labels, line_labels)

# %%
list0 = [70, 70, 69, 68, 67, 64, 60, 57, 55, 52]
list1 = [76, 76, 75, 71, 70, 67, 62, 61, 61, 57]
list2 = [76, 75, 76, 75, 74, 70, 68, 68, 63, 60]
# list3 = [77, 76, 75, 73, 72, 69, 65, 63]
# list4 = [80, 78, 77, 75, 72, 71, 69, 67]
list5 = [85, 85, 84, 81, 79, 79, 75, 74, 69, 67]
# list6 = [83, 82, 78, 79, 76, 75, 70, 67]
list7 = [85, 85, 85, 83, 82, 80, 78, 77, 72, 70]
list8 = [85, 85, 85, 83, 82, 80, 78, 77, 72, 70]
list9 = [85, 85, 85, 84, 82, 80, 78, 77, 73, 70]

x_labels = [
    '200-500', '500-1000','1000-2000', '2000-3000', '3000-4000', '4000-5000',
    '5000-6000', '6000-7000', '7000-8000', '8000-9000'
]
line_labels = [
    'Training using 0 x1000-nodes graphs',
    # 'Training Graph 2x1000-node',
    # 'Training Graph 3x1000-node',
    'Training using 6 x1000-nodes graphs',
    # 'Training Graph 5x1000-node',
    'Training using 10 x1000-nodes graphs',
    # 'Training Graph 8x1000-node',
    'Training using 14 x1000-nodes graphs',
    'Training using 18 x1000-nodes graphs',
    'Training using 22 x1000-nodes graphs',
    'Training using 400 x1000-nodes graphs',
]


# Combine all data lists in a single list
# data_lists = [list0, list1, list2, list3, list4, list5, list6, list7, list8, list9]
data_lists = [list0, list1,  list2, list5, list7, list8, list9]
create_line_graph(data_lists, x_labels, line_labels, y_lim=50, index=4)

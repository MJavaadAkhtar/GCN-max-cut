# %%
from networkx.algorithms.flow import shortest_augmenting_path, minimum_cut_value
import networkx as nx
import itertools
import pickle
import dgl
import torch
from collections import OrderedDict, defaultdict
from commons import *
import os

# %%
TORCH_DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
TORCH_DTYPE = torch.float32
def swap_graph_nodes(graph, mapping):
    """
    Swap the nodes of a NetworkX graph according to a given mapping dictionary, ensuring mutual swaps.

    :param graph: NetworkX graph
    :param mapping: dictionary where keys and values represent nodes to be swapped
    :return: None; the graph is modified in place
    """
    # Create a temporary mapping to intermediate labels
    temp_mapping = {old_label: max(graph.nodes) + 1 + i for i, old_label in enumerate(mapping)}

    # First step: move all nodes to temporary labels
    nx.relabel_nodes(graph, mapping=temp_mapping, copy=False)

    # Create the reverse of the initial mapping to complete the swap
    reverse_mapping = {value: key for key, value in mapping.items()}

    # Second step: from temporary labels to final labels
    nx.relabel_nodes(graph, mapping={temp_mapping[old]: reverse_mapping[old] for old in mapping}, copy=False)

# %%
def create_graph(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # The first line contains the terminal nodes, remove brackets and split
    terminal_list = lines[0].strip()[1:-1].split(',')
    terminal_list = [int(node) for node in terminal_list]

    # Create a new graph
    test_graph = nx.Graph()

    # Add edges from the remaining lines
    for line in lines[1:]:
        parts = line.split()
        if len(parts) == 3:
            from_node = int(parts[0])
            to_node = int(parts[1])
            capacity = float(parts[2])
            test_graph.add_edge(from_node, to_node, capacity=capacity, weight=capacity)

    return test_graph, terminal_list

def process_all_files(directory):
    graphs = {}
    terminal_lists = {}

    # Loop through all files in the directory
    for filename in os.listdir(directory):
        if filename.endswith(".txt"):  # Check if the file is a .txt file
            file_path = os.path.join(directory, filename)
            graph, terminals = create_graph(file_path)
            graphs[filename] = graph
            terminal_lists[filename] = terminals

    return graphs, terminal_lists

# %%
def createGraphFromFolder(dst):

    # Example usage
    directory =  dst # Replace this with your directory path
    all_graphs, all_terminals = process_all_files(directory)

    datasetItem = {}
    i = 0
    skipped = 0
    try:
        # Print out some details about the graphs (optional)
        for filename, graph in all_graphs.items():
            # print(f"Graph for {filename}: Nodes = {graph.nodes()}, Edges = {graph.edges(data=True)}")
            # print(f"Terminals for {filename}: {all_terminals[filename]}")
            terminals = all_terminals[filename]
            if 0 not in terminals and 1 not in terminals and 2 not in terminals:
                swap_graph_nodes(graph, {terminals[0]:0, terminals[1]:1, terminals[2]:2, 0:terminals[0], 1:terminals[1], 2:terminals[2]})
            elif 0 not in terminals and 1 not in terminals and 2 in terminals:
                terminals.sort()
                swap_graph_nodes(graph, {terminals[1]:0, terminals[2]:1,  0:terminals[1], 1:terminals[2]})
            elif 0 not in terminals and 1  in terminals and 2 not in terminals:
                terminals.sort()
                swap_graph_nodes(graph, {terminals[1]:0, terminals[2]:2,  0:terminals[1], 2:terminals[2]})
            elif 0  in terminals and 1 not in terminals and 2 not in terminals:
                terminals.sort()
                swap_graph_nodes(graph, {terminals[1]:1, terminals[2]:2,  1:terminals[1], 2:terminals[2]})
            else:
                skipped +=1
                continue
            graph_dgl = dgl.from_networkx(nx_graph=graph)
            graph_dgl = graph_dgl.to(TORCH_DEVICE)
            q_torch = qubo_dict_to_torch(graph, gen_adj_matrix(graph), torch_dtype=TORCH_DTYPE, torch_device=TORCH_DEVICE)

            # datasetItem[i] = [graph_dgl, q_torch, graph, all_terminals[filename]]
            datasetItem[i] = [graph_dgl, q_torch, graph, [0,1,2]]
            i+=1

    except:
        print(i, filename, terminals, graph.edges())

    print(skipped)
    return datasetItem

# %%
save_object(createGraphFromFolder('/Users/javaad/Documents/research/COP/testData/testDataTxt'), './testData/prepareDS.pkl')
# Out:
# 0

# %%
def recursive_cut(graph, terminals):
    if len(terminals) <= 1 or graph.number_of_nodes() == 0:
        # Base case: no cut needed if only one terminal or graph is empty
        return 0, {terminals[0]: graph} if terminals else {}

    # Perform initial 2-way cut between the first two terminals
    cut_value, (part_1, part_2) = nx.minimum_cut(graph, terminals[0], terminals[1], flow_func=shortest_augmenting_path)
    graph_1, graph_2 = graph.subgraph(part_1).copy(), graph.subgraph(part_2).copy()

    # Determine which terminals are in each subgraph
    terminals_1, terminals_2 = [], []
    for terminal in terminals:
        if terminal in part_1:
            terminals_1.append(terminal)
        else:
            terminals_2.append(terminal)

    # Recursively apply cuts to each subgraph
    cut_value_1, partitions_1 = recursive_cut(graph_1, terminals_1)
    cut_value_2, partitions_2 = recursive_cut(graph_2, terminals_2)

    # Combine the results
    total_cut_value = cut_value + cut_value_1 + cut_value_2
    partitions = partitions_1
    partitions.update(partitions_2)  # Merge the two partition dictionaries

    return total_cut_value, partitions
def find_k_way_cut(graph, terminals):
    """
    Find a k-way cut in the graph such that all terminals are in separate partitions.

    Parameters:
    - graph: A NetworkX graph.
    - terminals: A list of terminal nodes that need to be in separate partitions.

    Returns:
    - The total cut value for separating all terminals into their own partition.
    - A dictionary mapping each terminal to its corresponding subgraph.
    """

    permutations = list(itertools.permutations(terminals))
    best_cut_Value = torch.inf
    best_partition = []
    for perm in permutations:
        total_cut_value, partitions = recursive_cut(graph, perm)
        if total_cut_value < best_cut_Value:
            best_cut_Value = total_cut_value
            best_partition = partitions

    # total_cut_value, partitions = recursive_cut(graph, terminals)
    # return total_cut_value, partitions
    return best_cut_Value, best_partition

# %%
test_item = {}
test_item = open_file(obj = test_item, filename='./testData/prepareDS.pkl')

heurestic_cut_k = []
for key, (dgl_graph, adjacency_matrix,graph, terminals) in test_item.items():

    l = find_k_way_cut(graph, terminals)
    # print(l)
    heurestic_cut_k.append(l[0])
    print("Heurestic k-way 3 min-cut value: " + str(heurestic_cut_k[-1]), l[1][terminals[0]].number_of_nodes(), l[1][terminals[1]].number_of_nodes(), l[1][terminals[2]].number_of_nodes(), terminals)
# Out:
# Heurestic k-way 3 min-cut value: 92.0 15 61 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 20 31 29 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 20.0 56 5 19 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 98.0 48 23 9 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 6.0 40 29 11 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 121.0 14 4 62 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 32.0 43 28 9 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 6.0 7 23 50 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 41.0 50 24 6 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 18.0 9 2 69 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 29.0 22 53 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 59.0 23 52 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 5.0 6 31 43 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 19.0 5 44 31 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 3.0 20 25 35 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 3.0 36 28 16 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 64.0 5 30 45 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 6.0 46 15 19 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 49.0 34 40 6 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 6.0 26 27 27 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 70.0 24 52 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 38.0 7 68 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 41.0 9 67 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 29.0 22 5 53 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 21.0 39 5 36 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 92.0 10 60 10 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 6.0 47 15 18 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 38.0 5 3 72 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 19.0 41 6 33 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 27 37 16 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 10.0 15 27 38 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 3.0 66 7 7 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 32 23 25 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 37.0 9 66 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 73.0 3 63 14 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 35.0 65 8 7 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 37.0 4 53 23 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 15.0 57 13 10 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 35 31 14 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 39.0 6 46 28 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 14.0 22 51 7 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 37.0 44 23 13 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 6.0 38 8 34 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 19.0 21 53 6 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 26.0 61 13 6 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 137.0 71 4 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 4.0 23 38 19 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 4.0 23 36 21 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 26.0 59 15 6 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 52.0 10 5 65 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 10 3 67 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 104.0 3 6 71 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 53.0 8 9 63 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 5.0 43 5 32 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 15.0 11 8 61 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 99.0 31 34 15 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 21.0 9 48 23 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 80.0 44 8 28 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 42.0 42 1 37 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 38 27 15 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 162.0 9 9 62 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 63.0 7 51 22 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 28.0 29 46 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 81.0 67 4 9 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 7.0 38 20 22 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 48.0 33 8 39 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 3.0 19 53 8 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 4.0 50 10 20 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 158.0 3 4 73 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 22.0 8 19 53 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 11.0 47 19 14 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 106.0 46 5 29 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 5.0 33 2 45 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 158.0 4 22 54 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 4.0 19 36 25 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 56.0 5 57 18 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 47.0 5 51 24 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 54.0 5 52 23 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 6.0 40 34 6 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 3.0 34 18 28 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 15.0 30 40 10 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 69.0 64 8 8 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 98.0 4 7 69 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 22.0 6 6 68 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 25 40 15 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 3.0 19 24 37 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 25.0 52 5 23 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 28 31 21 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 80.0 62 14 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 3.0 58 6 16 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 17.0 4 47 29 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 31 30 19 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 3.0 34 16 30 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 38.0 5 28 47 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 39.0 4 69 7 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 93.0 52 23 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 32 28 20 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 57 11 12 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 23.0 20 18 42 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 129.0 2 29 49 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 5.0 36 39 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 90.0 39 35 6 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 48.0 39 36 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 4.0 67 5 8 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 52.0 18 50 12 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 36.0 25 51 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 19.0 4 4 72 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 49.0 3 54 23 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 43.0 47 28 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 25.0 26 4 50 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 25.0 66 5 9 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 106.0 52 25 3 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 5.0 12 21 47 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 37.0 19 38 23 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 3.0 34 17 29 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 112.0 5 6 69 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 171.0 6 61 13 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 43.0 33 6 41 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 32.0 46 30 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 87.0 41 35 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 19.0 10 63 7 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 51.0 9 54 17 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 130.0 3 3 74 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 66.0 48 6 26 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 6.0 9 53 18 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 23.0 9 65 6 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 64.0 5 71 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 26 19 35 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 20.0 23 12 45 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 15.0 58 13 9 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 26.0 5 7 68 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 4.0 41 14 25 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 11.0 9 60 11 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 108.0 49 3 28 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 34.0 10 47 23 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 28.0 37 7 36 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 11.0 23 36 21 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 56.0 28 9 43 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 24.0 4 71 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 5.0 14 24 42 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 5.0 47 21 12 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 5.0 39 25 16 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 127.0 69 4 7 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 42.0 8 68 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 38.0 55 16 9 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 51.0 48 28 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 14.0 15 38 27 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 37.0 14 20 46 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 29.0 4 17 59 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 93.0 7 67 6 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 15.0 7 31 42 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 9.0 5 48 27 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 9.0 6 7 67 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 47.0 10 9 61 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 33 29 18 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 45.0 29 14 37 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 44.0 38 34 8 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 55.0 71 5 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 13.0 10 11 59 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 17.0 32 44 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 20.0 47 17 16 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 17.0 27 23 30 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 47.0 29 43 8 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 34.0 10 5 65 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 46.0 6 30 44 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 37 33 10 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 18.0 11 46 23 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 36.0 14 60 6 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 6.0 26 13 41 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 35.0 20 55 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 5.0 48 13 19 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 26 19 35 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 18.0 53 23 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 7.0 6 55 19 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 18.0 49 4 27 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 7.0 14 33 33 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 75.0 4 35 41 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 123.0 52 3 25 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 12.0 9 14 57 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 10.0 42 4 34 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 3.0 7 48 25 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 40.0 6 70 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 63 5 12 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 9.0 29 10 41 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 10.0 10 10 60 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 12.0 10 39 31 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 34.0 4 41 35 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 20.0 67 6 7 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 17.0 13 2 65 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 10.0 32 23 25 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 41 26 13 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 6.0 29 36 15 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 81.0 8 14 58 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 4.0 41 18 21 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 15.0 10 5 65 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 26.0 40 35 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 5.0 32 21 27 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 11.0 56 12 12 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 9.0 26 41 13 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 4.0 26 37 17 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 12.0 21 18 41 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 81.0 50 26 4 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 28.0 8 48 24 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 42.0 42 13 25 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 93.0 12 11 57 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 3.0 39 33 8 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 20.0 27 41 12 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 11.0 22 32 26 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 9.0 29 32 19 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 64.0 34 7 39 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 7.0 47 28 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 48.0 28 9 43 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 9.0 13 38 29 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 42.0 37 40 3 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 68.0 10 4 66 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 4.0 26 47 7 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 17.0 8 27 45 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 6.0 29 23 28 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 50.0 9 37 34 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 37.0 61 11 8 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 38.0 57 5 18 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 26.0 8 4 68 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 22 40 18 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 18.0 20 47 13 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 6.0 30 29 21 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 10.0 29 15 36 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 14.0 49 28 3 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 6.0 53 7 20 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 11.0 25 26 29 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 85.0 5 63 12 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 10.0 52 11 17 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 9.0 51 8 21 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 71.0 4 5 71 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 28.0 19 3 58 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 19.0 8 54 18 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 8.0 23 39 18 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 19.0 34 39 7 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 65 10 5 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 30.0 4 61 15 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 58.0 6 66 8 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 13 38 29 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 106.0 4 13 63 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 37.0 19 16 45 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 81.0 43 22 15 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 5.0 17 44 19 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 36.0 9 7 64 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 53.0 4 11 65 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 2.0 38 23 19 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 3.0 34 39 7 [0, 1, 2]
# Heurestic k-way 3 min-cut value: 4.0 45 22 13 [0, 1, 2]
